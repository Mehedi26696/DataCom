# %% [markdown]
# <center><h1>NRZ-L Encoding and Decoding Python Impelementation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bits = '10110010'

# %%
bits_list = [int(char) for char in bits]
print(bits_list)
# Out:
# [1, 0, 1, 1, 0, 0, 1, 0]

# %% [markdown]
# <b>Plot Signal

# %%
def plot_signal(encoded_signal):
    time = range(len(encoded_signal)+1)
    signal = encoded_signal + [encoded_signal[-1]]
    plt.step(time, signal, where='post')
    plt.xlabel('Time')
    plt.ylabel('Signal Level')
    plt.title('NRZ-L Input')
    plt.grid(True)
    plt.savefig("NRZ-L_input_plot.png", dpi=300, bbox_inches='tight')
    plt.show()

# %%
plot_signal(bits_list)

# %% [markdown]
# <b>Encoding

# %%
def nrz_l_encode(bits):
    # NRZ-L encoding: 1 -> +1, 0 -> 0
    encoded_signal =[]
    for bit in bits:
        if bit == '1':
            encoded_signal.append(1)
        else:
            encoded_signal.append(0)
    return encoded_signal

# %%
encoded_signal = nrz_l_encode(bits)
print(f"Encoded Signal: {encoded_signal}")
# Out:
# Encoded Signal: [1, 0, 1, 1, 0, 0, 1, 0]

# %% [markdown]
# <b>Plot Signal

# %%
def plot_signal_encoding(encoded_data):
    time = range(len(encoded_signal)+1)
    signal = encoded_signal + [encoded_signal[-1]]
    plt.step(time, signal, where='post')

    # Plot the signal
    plt.title("NRZ-L Encoding")
    plt.xlabel("Time")
    plt.ylabel("Voltage")
    plt.grid(True)
    plt.savefig("NRZ-L_Encoding.png", dpi=300, bbox_inches='tight')
    plt.show()

# %%
plot_signal_encoding(encoded_signal)

# %% [markdown]
# <b>Decoding

# %%
def nrz_l_decode(encoded_data):
    # NRZ-L decoding: +1 -> 1, 0 -> 0
    decoded_data = ''
    for value in encoded_data:
        if value == 1:
            decoded_data += '1'
        else:
            decoded_data += '0'
    return decoded_data

# %%
decoded_data = nrz_l_decode(encoded_signal)
print(f"Decoded Signal: {decoded_data}")
# Out:
# Decoded Signal: 10110010

# %%
decoded_signal= [int(char) for char in decoded_data]
print(decoded_signal)
# Out:
# [1, 0, 1, 1, 0, 0, 1, 0]

# %% [markdown]
# <b>Plot Signal

# %%
def plot_signal_decode(encoded_signal):
    time = range(len(encoded_signal)+1)
    signal = encoded_signal + [encoded_signal[-1]]
    plt.step(time, signal, where='post')
    plt.xlabel('Time')
    plt.ylabel('Signal Level')
    plt.title('NRZ-L Decoding')
    plt.grid(True)
    plt.savefig("NRZ-L_Decoding.png", dpi=300, bbox_inches='tight')
    plt.show()

# %%
plot_signal_decode(decoded_signal)
